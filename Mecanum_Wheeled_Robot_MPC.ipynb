# %% [markdown]
# <a href="https://colab.research.google.com/github/Praful22/Mecanum_wheeled_robot_MPC/blob/main/Mecanum_Wheeled_Robot_MPC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mecanum Wheeled Robot:
#
# A mecanum wheeled robot gets its name from Mecanum AB company which is a omnidirectional wheeled robot design for land-based 2-D vehicle to move in any direction.
#
# # Mechanisms of Movement of Mecanum Wheeled Robot:
# 1.
#
# 2.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
